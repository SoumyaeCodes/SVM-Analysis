# %%
#Data visualizing and cleaning
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
#Traning Testing and Spliting Data
from sklearn.model_selection import train_test_split
#for label encoding 
from sklearn.preprocessing import LabelEncoder
# Scale the data to be between -1 and 1
from sklearn.preprocessing import StandardScaler
#for SVM
from sklearn.svm import SVC
from sklearn import metrics
#Using Cross Validation
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv('../Dataset/voice.csv')
df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %%
df.corr()
# Out:
#           meanfreq        sd    median       Q25       Q75       IQR  \
# meanfreq  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# sd       -0.739039  1.000000 -0.562603 -0.846931 -0.161076  0.874660
# median    0.925445 -0.562603  1.000000  0.774922  0.731849 -0.477352
# Q25       0.911416 -0.846931  0.774922  1.000000  0.477140 -0.874189
# Q75       0.740997 -0.161076  0.731849  0.477140  1.000000  0.009636
# IQR      -0.627605  0.874660 -0.477352 -0.874189  0.009636  1.000000
# skew     -0.322327  0.314597 -0.257407 -0.319475 -0.206339  0.249497
# kurt     -0.316036  0.346241 -0.243382 -0.350182 -0.148881  0.316185
# sp.ent   -0.601203  0.716620 -0.502005 -0.648126 -0.174905  0.640813
# sfm      -0.784332  0.838086 -0.661690 -0.766875 -0.378198  0.663601
# mode      0.687715 -0.529150  0.677433  0.591277  0.486857 -0.403764
# centroid  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# meanfun   0.460844 -0.466281  0.414909  0.545035  0.155091 -0.534462
# ...

# %%
plt.figure(figsize=(20,20))
data_corr = df.corr()
sb.heatmap(data_corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %%
df.shape
# Out:
# (3168, 21)

# %%
print("Total number of labels: {}".format(df.shape[0]))
print("Number of male: {}".format(df[df.label == 'male'].shape[0]))
print("Number of female: {}".format(df[df.label == 'female'].shape[0]))
# Out:
# Total number of labels: 3168
# Number of male: 1584
# Number of female: 1584

# %%
df.isnull().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
X = df.drop('label', axis=1)
y = df['label']

# %%
gender_encoder = LabelEncoder()
y = gender_encoder.fit_transform(y)
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
svc=SVC(kernel='poly') #Default hyperparameters
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.9589905362776026

# %%
print('Accuracy Score\'s are:')
acc=[]
gamma=['scale','auto']
for i in gamma:
    for j in range(10):
        svc=SVC(kernel='poly',degree=j,gamma=i ) 
        svc.fit(X_train,y_train)
        y_pred=svc.predict(X_test)
        print('For degree ',j,'gamma as ',i,' =',metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score's are:
# For degree  0 gamma as  scale  = 0.49053627760252366
# For degree  1 gamma as  scale  = 0.9716088328075709
# For degree  2 gamma as  scale  = 0.9085173501577287
# For degree  3 gamma as  scale  = 0.9589905362776026
# For degree  4 gamma as  scale  = 0.8769716088328076
# For degree  5 gamma as  scale  = 0.8753943217665615
# For degree  6 gamma as  scale  = 0.8138801261829653
# For degree  7 gamma as  scale  = 0.807570977917981
# For degree  8 gamma as  scale  = 0.7586750788643533
# For degree  9 gamma as  scale  = 0.7570977917981072
# For degree  0 gamma as  auto  = 0.49053627760252366
# For degree  1 gamma as  auto  = 0.9716088328075709
# For degree  2 gamma as  auto  = 0.9085173501577287
# For degree  3 gamma as  auto  = 0.9589905362776026
# For degree  4 gamma as  auto  = 0.8769716088328076
# For degree  5 gamma as  auto  = 0.8753943217665615
# For degree  6 gamma as  auto  = 0.8091482649842271
# For degree  7 gamma as  auto  = 0.804416403785489
# ...

# %%
#for gamma as scale
C_range=[0.1,1,10]
acc_score=[]
for c in C_range:
    svc = SVC(kernel='poly', C=c,degree=1,gamma='scale')
    scores = cross_val_score(svc, X, y, cv=10, scoring='accuracy')
    acc_score.append(scores.mean())
print(acc_score)
# Out:
# [0.9652807171664737, 0.9703320289102745, 0.9696991175178692]

# %%
C_range=[0.1,1,10]
plt.figure(figsize=(20,20))


plt.plot(C_range,acc_score)
plt.xlabel('Value of C for SVC ')
plt.xticks(np.arange(0.1,10,1.5))
plt.ylabel('Cross-Validated Accuracy')
# Out:
# Text(0, 0.5, 'Cross-Validated Accuracy')

# %%
print('Accuracy Score\'s are:')

svc=SVC(kernel='poly',gamma='scale',degree=1,C=1.5  ) 
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score's are:
# 0.9747634069400631

# %%
#for gamma as auto
C_range=[0.1,1,10]
acc_score=[]
for c in C_range:
    svc = SVC(kernel='poly', C=c,degree=1,gamma='auto')
    scores = cross_val_score(svc, X, y, cv=10, scoring='accuracy')
    acc_score.append(scores.mean())
print(acc_score)
# Out:
# [0.9652807171664737, 0.9706474863235236, 0.9696991175178692]

# %%
C_range=[0.1,1,10]
plt.figure(figsize=(20,20))


plt.plot(C_range,acc_score)
plt.xlabel('Value of C for SVC ')
plt.xticks(np.arange(0.1,10,1.5))
plt.ylabel('Cross-Validated Accuracy')
# Out:
# Text(0, 0.5, 'Cross-Validated Accuracy')

# %%
# print('Accuracy Score\'s are:')

# svc=SVC(kernel='poly',gamma='auto',degree=1,C=1.5  ) 
# svc.fit(X_train,y_train)
# g_range=[0.51,0.52,0.53,0.54,0.56,0.55]
# plt.figure(figsize=(20,20))


# plt.plot(g_range,acc_score)
# plt.xlabel('Value of C for SVC ')
# plt.xticks(np.arange(0.50,0.57,0.01))
# plt.ylabel('Cross-Validated Accuracy')
# y_pred=svc.predict(X_test)
# print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score's are:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-384c6d4f752e> in <module>
#       7
#       8
# ----> 9 plt.plot(g_range,acc_score)
#      10 plt.xlabel('Value of C for SVC ')
#      11 plt.xticks(np.arange(0.50,0.57,0.01))
#
# ~\.conda\envs\Virtual_env_DL\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\.conda\envs\Virtual_env_DL\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
# ...

# %%
# gamma as numbers
g_range=[0.51,0.52,0.53,0.54,0.56,0.55]
acc_score=[]
for g in g_range:
    svc = SVC(kernel='poly', C=1.5,degree=1,gamma=g)
    scores = cross_val_score(svc, X, y, cv=10, scoring='accuracy')
    acc_score.append(scores.mean())
print(acc_score)
# Out:
# [0.9700145749311183, 0.9700145749311183, 0.9696981192349158, 0.9696981192349158, 0.9696981192349158, 0.9696981192349158]

# %%
g_range=[0.51,0.52,0.53,0.54,0.56,0.55]
plt.figure(figsize=(20,20))


plt.plot(g_range,acc_score)
plt.xlabel('Value of C for SVC ')
plt.xticks(np.arange(0.51,0.57,0.01))
plt.ylabel('Cross-Validated Accuracy')
# Out:
# Text(0, 0.5, 'Cross-Validated Accuracy')

# %%
#gamma as 0.52

# %%
svc = SVC(kernel='poly', C=1.5,degree=1,gamma=0.515)
scores = cross_val_score(svc, X, y, cv=10, scoring='accuracy')
print(scores.mean())
# Out:
# 0.9700145749311183

# %%
print('Accuracy Score\'s are:')

svc=SVC(kernel='poly',gamma='auto',degree=1,C=1.5  ) 
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score's are:
# 0.9747634069400631
