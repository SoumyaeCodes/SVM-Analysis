# %%
#Data visualizing and cleaning
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#Traning Testing and Spliting Data
from sklearn.model_selection import train_test_split
#for label encoding 
from sklearn.preprocessing import LabelEncoder
# Scale the data to be between -1 and 1
from sklearn.preprocessing import StandardScaler
#for SVM
from sklearn.svm import SVC
from sklearn import metrics
#Using Cross Validation
from sklearn.model_selection import cross_val_score
from matplotlib import style
style.use('ggplot')
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
#For confusion matrixes
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('../Dataset/voice.csv')
X = df.drop('label', axis=1)
y = df['label']
gender_encoder = LabelEncoder()
y = gender_encoder.fit_transform(y)
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# # SVM Classification Score for rbf

# %%
from sklearn.svm import SVC
svm = SVC(kernel='rbf',gamma=0.5, C=1.9000000000000001)
svm.fit(X_train,y_train)
print("SVM Classification Score for rbf is : {}".format(svm.score(X_test,y_test)))
# method_names.append("SVM")
# method_scores.append(svm.score(x_test,y_test))

#Confusion Matrix
y_pred = svm.predict(X_test)
conf_mat = confusion_matrix(y_test,y_pred)
#Visualization Confusion Matrix
f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted Values")
plt.ylabel("True Values")
plt.show()
# Out:
# SVM Classification Score for rbf is : 0.9763406940063092

# %% [markdown]
# # SVM Classification Score for poly

# %%
from sklearn.svm import SVC
svm = SVC(kernel='poly',gamma='auto',degree=1,C=1.5  )
svm.fit(X_train,y_train)
print("SVM Classification Score for poly is : {}".format(svm.score(X_test,y_test)))
# method_names.append("SVM")
# method_scores.append(svm.score(x_test,y_test))

#Confusion Matrix
y_pred = svm.predict(X_test)
conf_mat = confusion_matrix(y_test,y_pred)
#Visualization Confusion Matrix
f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted Values")
plt.ylabel("True Values")
plt.show()
# Out:
# SVM Classification Score for poly is : 0.9747634069400631

# %% [markdown]
# # SVM Classification Score for sigmoid

# %%
from sklearn.svm import SVC
svm = SVC(kernel='sigmoid',C=1.5, gamma=0.004)
svm.fit(X_train,y_train)
print("SVM Classification Scorefor sigmoid is : {}".format(svm.score(X_test,y_test)))
# method_names.append("SVM")
# method_scores.append(svm.score(x_test,y_test))

#Confusion Matrix
y_pred = svm.predict(X_test)
conf_mat = confusion_matrix(y_test,y_pred)
#Visualization Confusion Matrix
f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted Values")
plt.ylabel("True Values")
plt.show()
# Out:
# SVM Classification Scorefor sigmoid is : 0.9637223974763407

# %% [markdown]
# # SVM Classification Score for Linear

# %%
from sklearn.svm import SVC
svm = LinearSVC(C=1,dual = True,max_iter=1000000,penalty='l2',loss='hinge')
svm.fit(X_train,y_train)
print("SVM Classification Score for Linear is : {}".format(svm.score(X_test,y_test)))
# method_names.append("SVM")
# method_scores.append(svm.score(x_test,y_test))

#Confusion Matrix
y_pred = svm.predict(X_test)
conf_mat = confusion_matrix(y_test,y_pred)
#Visualization Confusion Matrix
f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted Values")
plt.ylabel("True Values")
plt.show()
# Out:
# SVM Classification Score for Linear is : 0.9779179810725552
