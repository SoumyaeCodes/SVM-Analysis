# %% [markdown]
# ## What is SVM?

# %% [markdown]
# <font size="4">(i) Powerful algorithm for solving optimization problem<br>
# (ii) Useful in classification as well as regression<br>
# (iii) High accuracy<br>
# (iv) Supports both linear and non-linear classification<br>
# (V) Supervised Algorithm</font><br>
# <br>
# <h2>Note:</h2> <font size="4">Aim of SVM is to select a hyperplane that is most optimal and tends to increase the margin of training data</font><br>
# <h2>Linearly and Non linearly separable data</h2>
# <h2 align="center">Linearly separable Data</h2>
# <img src="Images/1.png" title="Linearly Separable Data">
# <h2 align="center">Non Linearly separable Data</h2>
# <img src="Images/2.png" title="Linearly Separable Data">
# <br>
# <br>
# <h2>How SVM and perceptron are different?</h2><br><br>
# <h2>Core Concepts of SVM</h2><br>
# <font size="4">
# (i) Support Vectors<br>
# (ii) Margin<br>
# (iii) Hyperplane
#    </font>
#     <br><br>
# <h2>Hyperplane</h2><br>
# <font size="4">
# (i) Plane/space which segregates a set of data points as different classes<br>
# (ii) Aims to increase margin between two classes<br>
#     </font>
# <font size="4">
# Consider a case of two-dimensional linearly separable data. The data can be separated by a line. The function of the line y=ax+b can be modified by renaming x with x1 and y with x2. We get:-</font><br>
# <img src="Images/3.png"><br>
# <font size="4">We define x=(x1,x2) and w=(a,-1), we get:</font><br>
# <img src="Images/4.png"><br>
# <font size="4">Here, w refers to the normal to a plane and b refers to the bias</font><br>
# <img src="Images/5.png"><br>
# <font size="4">
# points above/on the hyperplane h==> +1<br>
# points below the hyperplane h==> -1<br>
# </font>
# <br>
# <br>
# <font size="4">
# Goal is to find the <u>Optimal Hyperplane</u> </font>
# <h2><br>SVM optimization problem</h2><br>
#
# <br><br>
# <h2>Key Terminologies</h2><br>
#
# <h2 align="center">(i) Overfitting and Underfitting</h2>
# <img src="Images/6.JPG"><br>
# <font size="4">
# <h2 align="center">(ii) Missclassification of points</h2>
# <img src="Images/20.jfif">
# </font>
# <h2 align="center">(iii) Hard Margin and Soft Margin</h2>
# <img src="Images/7.png"><br>
# <font size="4">
# <h2 align="center">(iv) Maximal Margin classifier</h2>
#     <img src="Images/21.jfif">
# </font>
# <br><br><br>
#
# <h2>Bias Variance Tradeoff</h2><br>
# <font size="4">
# (i) Higher Bias signified lower variance <br>
# (ii) Lower Bias signifies higher variance<br>
#    </font>
# <img src="Images/8.JPG"><br>
# <br><br>
# <h2>Hyperparameter Tuning</h2><br>
# <br>
# <h2>Regularization parameter</h2><br>
# <img src="Images/9.JPG"><br><br>
# <h2>Gamma</h2><br>
# <img src="Images/10.JPG"><br>
# <img src="Images/11.png"><br><br><br>
# <font size="4">
# Two types of SVMs:-</font><br>
# <h2>Linear SVMs</h2><br>
# <img src="Images/12.png"><br>
# <h2>Non Linear SVMs</h2><br>
# <img src="Images/13.png"><br>
# <br>
# <h2>Kernel Tricks</h2><br>
# <img src="Images/18.png"><br>
# <img src="Images/19.png"><br>
# <br><br>
# <h2>Key factors in SVM</h2><br>
# <font size="4">
# (i) Model Selection<br>
# </font>
#
# <h2 align="center">About Dataset</h2><br>
# <img src="Images/22.JPG"><br>
# <font size="4">
# (ii) Data Preparation<br>
# </font>
# <br>
# <h2> SVM Kernels </h2><br>
# <font size="4">
# (i) rbf Kernel<br>
# <img src="Images/15.png"><br><br>
# (ii) Poly kernel<br>
# <img src="Images/16.png"><br><br>
# (iii) Sigmoid Kernel<br>
# <img src="Images/17.png"><br><br>
# (iv) Linear Kernel<br>
# <img src="Images/23.JPG"><br><br>
# </font>
# <h2>Key lies in choosing the best possible Kernels</h2>
